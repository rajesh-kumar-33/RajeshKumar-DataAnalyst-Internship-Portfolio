# %%
#task 4:data storytelling and Statistical validation

# %%
## 1) Objective

the objective of this project is to analyze employee data to understand workforce characteristics,salary distribution
employee performance and remote work teams, the analysis helps in identifing meaningful insights that support better bussiness decision making.

# %%
## 2) Dataset Overview

the dataset contains employee infomation collected from theoraganization it includes details such as employee age,salary,department,
performance score,remote work status and employment status

Total Records:1020 employees

important attributes:

employee_ID
age
salary
department
performance_score
remote_work
status
join_Date

# %%
## 3) Data Preparation:

the dataset was cleaned and prepared before analysis

the following steps were performed:

checked missing values
verified data types
removed duplicate records
corrected inconsistent formatting
created new column such as Birth_Year
saved the final cleaned dataset
the preprocessing steps improved data quality andmade the dataset suitable for analysis

# %%
## 4) Key Performance Indicators(KPI's)

the following KPI's were identified

total employees
average employee age
average salary
employee performance distribution
remote work percentage

these KPI's help to understand workforce performance and employee characterstics

# %%
## finding key

the analysis produced the following findings:

most of employees belong to "Good" performance category
the average employee age is approximately 32 years
employees with higher performance scores generally recieve higher salaries.
remote work is adopted by consideration no of employees
salary distribution shows variation across different employee groups

# %%
## 6) Bisiness Impact

the analysis provides valuable information for management and decision making

the findings can be help the organization

improves employee performance
design better compensation statergies
understand workforce demographics
monitor remote work effectiveness
support human resource planning

# %%
## 7)Recommendations

based on the analysis the following recommendations are suggested:

provide training programs for lower performing employee
reward high performing employees
monitor employees statisfaction and productivity
improve the workforce planning using data driven decision
continue analyzing employee trends regularly

# %%
## 8. Conclusion

The employee data analysis provides useful insights into workforce performance, 
salary distribution, and employee characteristics. The organization can use these insights 
to improve decision-making and employee management.
    
The project demonstrates the importance of data analysis in solving business problems and generating actionable insights.
